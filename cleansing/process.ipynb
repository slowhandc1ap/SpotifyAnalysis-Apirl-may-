# %%
import pandas as pd 
import numpy as np

# %%
trackDF = pd.read_csv('featured_Spotify_track_info.csv')

# %%
trackDF.head()
# Out:
#                       ids                 names  popularity  markets  \
# 0  7lznzPjPyRFdcYaD9gN7a3     This Is Shangrila        45.0    152.0
# 1  3e2fDgC93LGc9Lbdvr6I9k       River Of Deceit        52.0    185.0
# 2  0donjzZGsCA2PfPUA4EdMN  Shadow of the Season        46.0    185.0
# 3  3bE5slaVEfaDreqARl6k4M      Yellow Ledbetter        69.0    183.0
# 4  1LvJ1PFobtIm5DwzRrK0jG      Swallow My Pride        43.0    185.0
#
#                   artists release_date  duration_ms  acousticness  \
# 0  3XR64HmFo4OvexUUNW7TP0   1990-01-01     220706.0      0.004280
# 1  0T7JQxpy1Li93vLNirbv0Z   1995-03-07     302693.0      0.111000
# 2  3Ukr3Ufjg8ygRJv7Ww887f         1992     273813.0      0.000046
# 3  1w5Kfo2jwwIPruYS2UWh56         1991     303586.0      0.290000
# 4  1XIIxzmo6BNRR4QkImSdsX   1990-09-13     179800.0      0.423000
#
#    danceability  energy  ...  loudness  speechiness    tempo  valence  \
# 0         0.467   0.774  ...   -10.617       0.0515  109.529    0.324
# ...

# %% [markdown]
# track.hist(figsize = (16,20), bins = 50) ;

# %%
import matplotlib.pyplot as plt
trackDF.hist(figsize=(16,20), bins = 50 )
# Out:
# array([[<Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'markets'}>,
#         <Axes: title={'center': 'duration_ms'}>,
#         <Axes: title={'center': 'acousticness'}>],
#        [<Axes: title={'center': 'danceability'}>,
#         <Axes: title={'center': 'energy'}>,
#         <Axes: title={'center': 'instrumentalness'}>,
#         <Axes: title={'center': 'liveness'}>],
#        [<Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'speechiness'}>,
#         <Axes: title={'center': 'tempo'}>,
#         <Axes: title={'center': 'valence'}>],
#        [<Axes: title={'center': 'musicalkey'}>,
#         <Axes: title={'center': 'musicalmode'}>,
#         <Axes: title={'center': 'time_signature'}>,
#         <Axes: title={'center': 'count'}>]], dtype=object)

# %%
trackDF.isna().sum()
# Out:
# ids                  0
# names                0
# popularity           0
# markets              0
# artists              0
# release_date         0
# duration_ms          0
# acousticness        14
# danceability        14
# energy              14
# instrumentalness    14
# liveness            14
# loudness            14
# speechiness         14
# tempo               14
# valence             14
# musicalkey          14
# musicalmode         14
# time_signature      14
# count                0
# dates                0
# playlists_found      0
# dtype: int64

# %%
trackDF.describe()
# Out:
#          popularity       markets   duration_ms  acousticness  danceability  \
# count  15052.000000  15052.000000  1.505200e+04  15038.000000  15038.000000
# mean      50.134135    173.076202  2.005013e+05      0.365888      0.567015
# std       17.968905     42.644276  5.827816e+04      0.368929      0.191950
# min        0.000000      0.000000  1.466000e+03      0.000001      0.000000
# 25%       39.000000    184.000000  1.630338e+05      0.029500      0.453000
# 50%       50.000000    185.000000  1.923360e+05      0.203000      0.590000
# 75%       63.000000    185.000000  2.271950e+05      0.719000      0.709000
# max      100.000000    185.000000  1.160720e+06      0.996000      0.978000
#
#              energy  instrumentalness      liveness      loudness  \
# count  15038.000000      15038.000000  15038.000000  15038.000000
# mean       0.556783          0.234196      0.167943    -10.811701
# std        0.296156          0.373847      0.127240      9.307152
# ...

# %%
dpTrack = trackDF.dropna(axis = 0)

# %%
dpTrack.isna().sum()
# Out:
# ids                 0
# names               0
# popularity          0
# markets             0
# artists             0
# release_date        0
# duration_ms         0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# musicalkey          0
# musicalmode         0
# time_signature      0
# count               0
# dates               0
# playlists_found     0
# dtype: int64

# %% [markdown]
# ___ CLEANSING ARTIST

# %%
artistDF = pd.read_csv('featured_Spotify_artist_info.csv')

# %%
artistDF.head(15)
# Out:
#          dates                     ids           names  monthly_listeners  \
# 0   2024-04-01  01XYiBYaoMJcNhPokrg0l0           stayc          3049521.0
# 1   2024-04-01  099toTcKJoywTosZr2hHjy  langhorne slim          1060777.0
# 2   2024-04-01  09HhJFJqYmvCCwQwj47Ci4         hontoni           119199.0
# 3   2024-04-01  09rAM5GlzBVG3FODKTlrRu         d'verti            46999.0
# 4   2024-04-01  0BvkDsjIUla7X0k6CSWh1I      luke bryan         10460890.0
# 5   2024-04-01  0CazI1GhvW5pqftM3uJA3l   phoenix feels            84567.0
# 6   2024-04-01  0CmvFWTX9zmMNCUi6fHtAx        the boyz          1285501.0
# 7   2024-04-01  0EXInuJq3g2Gz8pvxZCxer            priy           561554.0
# 8   2024-04-01  0FRUZvZNPzM3YJMABJxf2K           wendy          1885379.0
# 9   2024-04-01  0PzZEo9UXbMwpdcSZcSPfL      floatspace           106755.0
# 10  2024-04-01  0T7JQxpy1Li93vLNirbv0Z      mad season           568020.0
# 11  2024-04-01  0TjAAwE04BeoSeOpJIakYH      little may           221557.0
# ...

# %%
def clean_genres(genres):
    if pd.isna(genres):
        return genres
    # splitting by comma and 
    genre_list = genres.split(',')
    # keep only first word of each genres 
    # first_word = [genre.split()[0] for genre in genres_list]
    # return only first uniqe
    return genre_list[0]

# %%
artistDF['cleaningGenres'] = artistDF['genres'].apply(clean_genres)

# %%
artistDF.head(50)
# Out:
#          dates                     ids                   names  \
# 0   2024-04-01  01XYiBYaoMJcNhPokrg0l0                   stayc
# 1   2024-04-01  099toTcKJoywTosZr2hHjy          langhorne slim
# 2   2024-04-01  09HhJFJqYmvCCwQwj47Ci4                 hontoni
# 3   2024-04-01  09rAM5GlzBVG3FODKTlrRu                 d'verti
# 4   2024-04-01  0BvkDsjIUla7X0k6CSWh1I              luke bryan
# 5   2024-04-01  0CazI1GhvW5pqftM3uJA3l           phoenix feels
# 6   2024-04-01  0CmvFWTX9zmMNCUi6fHtAx                the boyz
# 7   2024-04-01  0EXInuJq3g2Gz8pvxZCxer                    priy
# 8   2024-04-01  0FRUZvZNPzM3YJMABJxf2K                   wendy
# 9   2024-04-01  0PzZEo9UXbMwpdcSZcSPfL              floatspace
# 10  2024-04-01  0T7JQxpy1Li93vLNirbv0Z              mad season
# 11  2024-04-01  0TjAAwE04BeoSeOpJIakYH              little may
# 12  2024-04-01  0UWgEdhywZEON8EtIBYGoL              john ocean
# 13  2024-04-01  0VG3jBtRm8GbFcIU7M4M7m          peaceful earth
# ...

# %%
artistDF.hist(figsize=(20,20), bins = 50 )
# Out:
# array([[<Axes: title={'center': 'monthly_listeners'}>,
#         <Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'followers'}>],
#        [<Axes: title={'center': 'first_release'}>,
#         <Axes: title={'center': 'last_release'}>,
#         <Axes: title={'center': 'num_releases'}>],
#        [<Axes: title={'center': 'num_tracks'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
artistDF.isna().sum()
# Out:
# dates                   0
# ids                     0
# names                   0
# monthly_listeners      47
# popularity              0
# followers               0
# genres               9101
# first_release           0
# last_release            0
# num_releases            0
# num_tracks              0
# playlists_found         0
# feat_track_ids          0
# cleaningGenres       9101
# dtype: int64

# %%
artistDF.describe()
# Out:
#        monthly_listeners    popularity     followers  first_release  \
# count       2.773500e+04  27782.000000  2.778200e+04   27782.000000
# mean        5.314222e+06     48.626377  2.090751e+06    1992.757757
# std         1.220245e+07     18.846193  7.965034e+06     213.370575
# min         0.000000e+00      0.000000  0.000000e+00      -1.000000
# 25%         1.213780e+05     36.000000  1.286250e+03    2013.000000
# 50%         5.315600e+05     48.000000  4.625100e+04    2019.000000
# 75%         3.778614e+06     62.000000  6.342625e+05    2021.000000
# max         1.140272e+08    100.000000  1.137957e+08    2024.000000
#
#        last_release  num_releases    num_tracks
# count  27782.000000  27782.000000  27782.000000
# mean    2001.176517     14.651573      2.362249
# std      210.956063      6.527520      3.760286
# min       -1.000000      0.000000      0.000000
# 25%     2023.000000      9.000000      1.000000
# 50%     2024.000000     20.000000      1.000000
# ...

# %%
artistDF = artistDF.drop(columns=['genres'])

# %%
artistDF.head(5)
# Out:
#         dates                     ids           names  monthly_listeners  \
# 0  2024-04-01  01XYiBYaoMJcNhPokrg0l0           stayc          3049521.0
# 1  2024-04-01  099toTcKJoywTosZr2hHjy  langhorne slim          1060777.0
# 2  2024-04-01  09HhJFJqYmvCCwQwj47Ci4         hontoni           119199.0
# 3  2024-04-01  09rAM5GlzBVG3FODKTlrRu         d'verti            46999.0
# 4  2024-04-01  0BvkDsjIUla7X0k6CSWh1I      luke bryan         10460890.0
#
#    popularity  followers  first_release  last_release  num_releases  \
# 0          63    1782552           2020          2024            14
# 1          51     163686           2008          2023            20
# 2          35         60           2021          2024            14
# 3          29         42           2022          2024             3
# 4          76    8487512           2007          2023            20
#
#    num_tracks                   playlists_found  \
# 0           2                     K-Pop ON! (온)
# ...

# %%
artistDF['cleaningGenres'].fillna('not define' , inplace= True)

# %%
artistDF.isna().sum()
# Out:
# dates                0
# ids                  0
# names                0
# monthly_listeners    0
# popularity           0
# followers            0
# first_release        0
# last_release         0
# num_releases         0
# num_tracks           0
# playlists_found      0
# feat_track_ids       0
# cleaningGenres       0
# dtype: int64

# %%
mode = artistDF['monthly_listeners'].mode()[0]

# %%
artistDF.fillna({'monthly_listeners' : mode}, inplace=True)

# %%
cor = artistDF.select_dtypes(include=[int,float]).corr()

# %%
pop = cor['popularity'].sort_values(ascending=False)

# %%
pop
# Out:
# popularity           1.000000
# monthly_listeners    0.655574
# num_releases         0.511919
# followers            0.448676
# last_release         0.155312
# first_release        0.143088
# num_tracks           0.109482
# Name: popularity, dtype: float64

# %%
artistDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27782 entries, 0 to 27781
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dates              27782 non-null  object
#  1   ids                27782 non-null  object
#  2   names              27782 non-null  object
#  3   monthly_listeners  27782 non-null  float64
#  4   popularity         27782 non-null  int64
#  5   followers          27782 non-null  int64
#  6   first_release      27782 non-null  int64
#  7   last_release       27782 non-null  int64
#  8   num_releases       27782 non-null  int64
#  9   num_tracks         27782 non-null  int64
#  10  playlists_found    27782 non-null  object
#  11  feat_track_ids     27782 non-null  object
#  12  cleaningGenres     27782 non-null  object
# dtypes: float64(1), int64(6), object(6)
# memory usage: 2.8+ MB

# %%
trackDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15052 entries, 0 to 15051
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ids               15052 non-null  object
#  1   names             15052 non-null  object
#  2   popularity        15052 non-null  float64
#  3   markets           15052 non-null  float64
#  4   artists           15052 non-null  object
#  5   release_date      15052 non-null  object
#  6   duration_ms       15052 non-null  float64
#  7   acousticness      15038 non-null  float64
#  8   danceability      15038 non-null  float64
#  9   energy            15038 non-null  float64
#  10  instrumentalness  15038 non-null  float64
#  11  liveness          15038 non-null  float64
#  12  loudness          15038 non-null  float64
#  13  speechiness       15038 non-null  float64
#  14  tempo             15038 non-null  float64
#  15  valence           15038 non-null  float64
# ...

# %%
trackDF.head(1)
# Out:
#                       ids              names  popularity  markets  \
# 0  7lznzPjPyRFdcYaD9gN7a3  This Is Shangrila        45.0    152.0
#
#                   artists release_date  duration_ms  acousticness  \
# 0  3XR64HmFo4OvexUUNW7TP0   1990-01-01     220706.0       0.00428
#
#    danceability  energy  ...  loudness  speechiness    tempo  valence  \
# 0         0.467   0.774  ...   -10.617       0.0515  109.529    0.324
#
#    musicalkey  musicalmode  time_signature  count       dates  playlists_found
# 0         4.0          0.0             4.0    1.0  2024-04-01   Grunge Forever
#
# [1 rows x 22 columns]

# %%
import mysql.connector  
from mysql.connector import Error

try:
      conn = mysql.connector.connect(
            host='localhost',
            database = 'spotify',
            user='root',
            password=''
      )
      if conn.is_connected():
            cursor = conn.cursor()
            print("connect!")

            # Define the CREATE TABLE query
            create_table_query = """
            CREATE TABLE IF NOT EXISTS track_info (
                  ids VARCHAR(255),
                  names VARCHAR(255),
                  popularity FLOAT,
                  markets FLOAT,
                  artists VARCHAR(255),
                  release_date DATE,
                  duration_ms FLOAT,
                  acousticness FLOAT,
                  danceability FLOAT,
                  energy FLOAT,
                  instrumentalness FLOAT,
                  liveness FLOAT,
                  loudness FLOAT,
                  speechiness FLOAT,
                  tempo FLOAT,
                  valence FLOAT,
                  musicalkey FLOAT,
                  musicalmode FLOAT,
                  time_signature FLOAT,
                  count FLOAT,
                  dates DATE,
                  playlists_found VARCHAR(255)
            )
            """

            # Execute the CREATE TABLE query
            cursor.execute(create_table_query)
            print("Table created successfully!")


            insert_query = """
            INSERT INTO track_info (ids, names, popularity, markets, artists, release_date, 
                                          duration_ms, acousticness, danceability, energy, instrumentalness, 
                                          liveness, loudness, speechiness, tempo, valence, musicalkey, 
                                          musicalmode, time_signature, count, dates, playlists_found)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            for index, row in dpTrack.iterrows():
                  cursor.execute(insert_query, (
                  row['ids'], row['names'], row['popularity'], row['markets'], row['artists'],
                  row['release_date'], row['duration_ms'], row['acousticness'], row['danceability'],
                  row['energy'], row['instrumentalness'], row['liveness'], row['loudness'], 
                  row['speechiness'], row['tempo'], row['valence'], row['musicalkey'], 
                  row['musicalmode'], row['time_signature'], row['count'], row['dates'], 
                  row['playlists_found']
                  ))
            # Commit the transaction
            conn.commit()
            print("Data inserted successfully!")

except Error as e:
      print("Error while connecting to MySQL", e)

finally:
    if conn.is_connected():
        cursor.close()
        conn.close()
        print("MySQL connection is closed")
# Out:
# connect!
# Table created successfully!
# Data inserted successfully!
# MySQL connection is closed

# %%
artistDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27782 entries, 0 to 27781
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dates              27782 non-null  object
#  1   ids                27782 non-null  object
#  2   names              27782 non-null  object
#  3   monthly_listeners  27782 non-null  float64
#  4   popularity         27782 non-null  int64
#  5   followers          27782 non-null  int64
#  6   first_release      27782 non-null  int64
#  7   last_release       27782 non-null  int64
#  8   num_releases       27782 non-null  int64
#  9   num_tracks         27782 non-null  int64
#  10  playlists_found    27782 non-null  object
#  11  feat_track_ids     27782 non-null  object
#  12  cleaningGenres     27782 non-null  object
# dtypes: float64(1), int64(6), object(6)
# memory usage: 2.8+ MB

# %%
import mysql.connector  
from mysql.connector import Error

try:
      conn = mysql.connector.connect(
            host='localhost',
            database = 'spotify',
            user='root',
            password=''
      )
      if conn.is_connected():
            cursor = conn.cursor()
            print("connect!")
            create_table_query = """
            CREATE TABLE IF NOT EXISTS artist_info (
                  dates DATE,
                  ids VARCHAR(255),
                  names VARCHAR(255),
                  monthly_listeners FLOAT,
                  popularity INT,
                  followers INT,
                  first_release INT, 
                  last_release INT, 
                  num_releases INT, 
                  num_tracks INT, 
                  playlists_found VARCHAR(255), 
                  feat_track_ids VARCHAR(255),
                  cleaningGenres VARCHAR(255)     
            )
            """

            # Execute the CREATE TABLE query
            cursor.execute(create_table_query)
            print("Table created successfully!")


            insert_query = """
            INSERT INTO artist_info (dates, ids, names, monthly_listeners,popularity, followers, first_release, last_release, 
                                          num_releases, num_tracks, playlists_found, feat_track_ids, cleaningGenres )
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
            """
            
            for index, row in artistDF.iterrows():
                  cursor.execute(insert_query, (
                  row['dates'], row['ids'], row['names'], row['monthly_listeners'],row['popularity'],
                  row['followers'], row['first_release'], row['last_release'], row['num_releases'], row['num_tracks'],
                  row['playlists_found'], row['feat_track_ids'], row['cleaningGenres']
                  ))
            # Commit the transaction
            conn.commit()
            print("Data inserted successfully!")

except Error as e:
      print("Error while connecting to MySQL", e)

finally:
    if conn.is_connected():
        cursor.close()
        conn.close()
        print("MySQL connection is closed")
# Out:
# connect!
# Table created successfully!
# Data inserted successfully!
# MySQL connection is closed

# %%
artistDF.head()
# Out:
#         dates                     ids           names  monthly_listeners  \
# 0  2024-04-01  1PnqJKNlsztufhgWQKb8C0           stayc          3049521.0
# 1  2024-04-01  1PnqJKNlsztufhgWQKb8C0  langhorne slim          1060777.0
# 2  2024-04-01  1PnqJKNlsztufhgWQKb8C0         hontoni           119199.0
# 3  2024-04-01  1PnqJKNlsztufhgWQKb8C0         d'verti            46999.0
# 4  2024-04-01  1PnqJKNlsztufhgWQKb8C0      luke bryan         10460890.0
#
#    popularity  followers  first_release  last_release  num_releases  \
# 0          63    1782552           2020          2024            14
# 1          51     163686           2008          2023            20
# 2          35         60           2021          2024            14
# 3          29         42           2022          2024             3
# 4          76    8487512           2007          2023            20
#
#    num_tracks                   playlists_found  \
# 0           2                     K-Pop ON! (온)
# ...

# %%
duplicate_rows = artistDF.duplicated(subset=['ids'])
print(artistDF[duplicate_rows])
# Out:
#             dates                     ids               names  \
# 188    2024-04-02  1PnqJKNlsztufhgWQKb8C0        aurora avery
# 191    2024-04-02  10exVja0key0uqUkk6LJRT           vance joy
# 194    2024-04-02  3JST5hIfjYPRqhKMJXqku2        los sobriles
# 196    2024-04-02  196lKsA13K3keVXMDFK66q  the avett brothers
# 197    2024-04-02  4TEK9tIkcoxib4GxT3O4ky        kiss of life
# ...           ...                     ...                 ...
# 27772  2024-05-09  4xFUf1FHVy696Q1JQZMTRj    carrie underwood
# 27774  2024-05-09  319yZVtYM9MBGqmSQnMyY6         carole king
# 27775  2024-05-09  2M0RKn1NTwiZsfqXuSaKpQ          banditerna
# 27777  2024-05-09  2YkhzcYyxJvtl5W6pY0PuF                camo
# 27781  2024-05-09  1SsVqqC31h54Hg08g7uQhM         yanghongwon
#
#        monthly_listeners  popularity  followers  first_release  last_release  \
# 188              68358.0          31         64           2021          2023
# ...

# %%
artistDF.duplicated(subset=['ids']).sum()
# Out:
# 17165

# %%
artistDF['ids'] = '1PnqJKNlsztufhgWQKb8C0'
